# %% [markdown]
# <a href="https://colab.research.google.com/github/VladimirPakhomov2000/Base-syntaxis-Python/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%91%D0%B0%D0%B7%D0%BE%D0%B2%D1%8B%D0%B9_%D0%B1%D0%BB%D0%BE%D0%BA_%7C_%D0%91%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B8_Numpy_%D0%B8_Matplotlib_%7C_%D0%94%D0%97_Ultra_Lite_(%D0%A2%D0%B5%D1%81%D1%82%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5)_%7C_%D0%A3%D0%98%D0%98%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1> <b> Инстуркция для сдачи домашнего задания «УльтраЛайт» </b> </h1>
# <p> <ul>
# <li> Запустите ячейку Установка инструментов». <br><i> (Начнется процесс установки необходимых инструментов, который займет несколько секунд)</i> </li>
# <li> Нажмите кнопку «Тестирование» </li>
# <li> При первом запуске появится окошко авторизации. <br> Введите свой логин (email) от учебной платформы и нажмите на кнопку «Приступить» </li>
# <li> После успешной авторизации появится тест из 10 вопросов <br> <i>Не забудьте прокрурить ползунок вверх, чтобы увидеть первые вопросы :) </i> </i>
# <li> Выберите по одному варианту ответа в каждом вопросе и нажмите кнопку «Проверить» </i>
# <li> После получения результата Вы можете пересдать тест или зачесть полученные баллы <i>(соответствующие кнопки «Пересдать» и «Зачесть ДЗ») </i> </li>
# <p> P.s. Вы можете в любой момент вернуться и пересдать домашнее задание для получения более высоких баллов
# <p> Успехов!

# %%
#@title Установка инструментов
# !rm -rf sample_data
# !rm -rf terraai
# !git clone -q https://github.com/gitterra/terrai-self-checking-homework terraai
from terraai import autocheck
worker = autocheck.Worker(11465, globals())

# %%
#@title Тестирование
from IPython.display import Javascript
worker.start()
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 5000})'''))
# Out:
# Вопрос №1:
# При запуске следующего кода:
#
# import numpy as np
# my_array = np.array(57, 322, 57, 11, 77)
#
# возникает ошибка. Какова причина этой ошибки?:
#
#
#       a) В функцию передается набор чисел. Необходимо подавать коллекцию элементов (например, список или кортеж)
#       b) Отсутствует точка с запятой в конце строк
#       c) Используется запрещенное имя переменной
#       d) Отсутствуют кавычки у каждого параметра функции np.array()
# ToggleButtons(options=('a', 'b', 'c', 'd'), tooltips=("'В функцию передается набор чисел. Необходимо подавать …
# Вопрос №2:
# В программе создан массив с помощью:
#
# my_array = np.random.randint(-5, 5, (4, 4))
#
# С помощью какого кода можно сделать "срез" массива,  состоящий из двух первых строк?:
#
#
#       a) my_array[:2]
#       b) my_array[2:]
#       c) my_array(,:2)
#       d) my_array(2:,)
# ToggleButtons(options=('a', 'b', 'c', 'd'), tooltips=("'my_array[:2]", " 'my_array[2:]", " 'my_array(,:2)", " …
# Вопрос №3:
# С помощью какой функции можно преобразовать массив размером (6, 6) в массив размером (36,)?:
#
#
#       a) shape
#       b) makeshape
#       c) change_shape
#       d) reshape
# ToggleButtons(options=('a', 'b', 'c', 'd'), tooltips=("'shape", " 'makeshape", " 'change_shape", " 'reshape'")…
# Вопрос №4:
# С помощью какой функции можно получить среднее значение массива?:
#
#
#       a) .mid()
#       b) .middle()
#       c) .mean()
#       d) .roll()
# ToggleButtons(options=('a', 'b', 'c', 'd'), tooltips=("'.mid()", " '.middle()", " '.mean()", " '.roll()'"), va…
# Вопрос №5:
# С помощью какой функции можно получить максиамльное значение массива?:
#
#
#       a) .max()
#       b) .maximum()
#       c) .big()
#       d) .large()
# ToggleButtons(options=('a', 'b', 'c', 'd'), tooltips=("'.max()", " '.maximum()", " '.big()", " '.large()'"), v…
# Вопрос №6:
# За что отвечает параметр linestyle функции .plot()?:
#
#
#       a) цвет линии
#       b) размер линии
#       c) стиль линии
#       d) шаг графика
# ToggleButtons(options=('a', 'b', 'c', 'd'), tooltips=("'цвет линии", " 'размер линии", " 'стиль линии", " 'шаг…
# Вопрос №7:
# С помощью какой пары функций можно задать подписи для осей графика?:
#
#
#       a) plt.xtypes() и plt.ytypes()
#       b) plt.xtext() и plt.ytext()
#       c) plt.xlabel() и plt.ylabel()
#       d) plt.xcaption() и plt.ycaption()
# ToggleButtons(options=('a', 'b', 'c', 'd'), tooltips=("'plt.xtypes() и plt.ytypes()", " 'plt.xtext() и plt.yte…
# Вопрос №8:
# Что будет являться результатом работы программы:
# np.linspace(5, 8, 100)?:
#
#
#       a) Массив элементов от 500 до 800
#       b) Массив из 100 элементов от 5 до 8 равноудаленных друг от друга
#       c) Массив из 5 элементов от 8 до 100
#       d) Трехмерный массив размерностью (5, 8, 100)
# ToggleButtons(options=('a', 'b', 'c', 'd'), tooltips=("'Массив элементов от 500 до 800", " 'Массив из 100 элем…
# Вопрос №9:
# С помощью какого атрибута можно узнать количество размерностей(осей) массива?
# (Именно количество размерностей. Не саму размерность):
#
#
#       a) .size
#       b) .dtype
#       c) .ndim
#       d) .razmer
# ToggleButtons(options=('a', 'b', 'c', 'd'), tooltips=("'.size", " '.dtype", " '.ndim", " '.razmer'"), value=No…
# Вопрос №10:
# Выберите верное утверждение.
# Функция np.arange(10) формирует ...:
#
#
#       a) список чисел от 0 до 10 включительно
#       b) кортеж чисел от 0 до 9 включительно
#       c) массив чисел от 0 до 10 включительно
#       d) массив чисел от 0 до 9 включительно
# ToggleButtons(options=('a', 'b', 'c', 'd'), tooltips=("'список чисел от 0 до 10 включительно", " 'кортеж чисел…
# Button(button_style='success', description='Проверить', icon='search', layout=Layout(display='block'), style=B…
# Ваш результат составил 9 баллов
#    * Для повторного тестирования нажмите «Пересдать»
#    * Для сдачи домшней работы нажмите «Зачесть ДЗ»
# Вы можете вернуться и пересдать домашнее задание в любое время
# Button(button_style='warning', description='Пересдать', icon='refresh', layout=Layout(display='block'), style=…
# Button(button_style='info', description='Зачесть ДЗ', icon='check-circle', layout=Layout(display='block'), sty…
